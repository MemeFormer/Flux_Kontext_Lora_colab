# %% [markdown]
# <a href="https://colab.research.google.com/github/MemeFormer/Flux_Kontext_Lora_colab/blob/main/flux_kontext_Face_Lora8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/
# !git clone https://huggingface.co/spaces/ginigen/Flux-Kontext-FaceLORA
# Out:
# /content
# Cloning into 'Flux-Kontext-FaceLORA'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 125 (delta 59), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (125/125), 339.66 KiB | 9.99 MiB/s, done.
# Resolving deltas: 100% (59/59), done.
# Encountered 1 file(s) that should have been pointers, but weren't:
# 	examples/1.png

# %%
# Change directory into the Gradio app's folder
# %cd /content/Flux-Kontext-FaceLORA

# Install all necessary Python libraries
# !pip install -r requirements.txt
# Out:
# /content/Flux-Kontext-FaceLORA
# ...
#   Cloning https://github.com/huggingface/diffusers.git to /tmp/pip-req-build-arx2jiz6
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/diffusers.git /tmp/pip-req-build-arx2jiz6
#   Resolved https://github.com/huggingface/diffusers.git to commit 6398fbc391519ce033d97d23925fd13ec4ed85a7
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 81.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# ...

# %%
# Create a directory in Google Drive to store your LoRA (if it doesn't exist)
# This will be /content/drive/MyDrive/ColabProjects/JD3_Nudify_Kontext_LoRa/
# !mkdir -p /content/drive/MyDrive/ColabProjects/JD3_Nudify_Kontext_LoRa/

# Download the .safetensors file directly into the created directory
# !wget -O /content/drive/MyDrive/ColabProjects/JD3_Nudify_Kontext_LoRa/JD3s_Nudify_Kontext.safetensors https://huggingface.co/JD3GEN/JD3_Nudify_Kontext_LoRa/resolve/main/JD3s_Nudify_Kontext.safetensors?download=true
# Out:
# --2025-07-14 20:07:54--  https://huggingface.co/JD3GEN/JD3_Nudify_Kontext_LoRa/resolve/main/JD3s_Nudify_Kontext.safetensors?download=true
# Resolving huggingface.co (huggingface.co)... 18.238.136.71, 18.238.136.32, 18.238.136.112, ...
# Connecting to huggingface.co (huggingface.co)|18.238.136.71|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from huggingface_hub import login
from google.colab import userdata

# Retrieve your token from Colab secrets
hf_token = userdata.get('Hugging_Face_Access_Token')

# Log in to Hugging Face
login(token=hf_token)

print("Successfully logged in to Hugging Face!")
# Out:
# Successfully logged in to Hugging Face!

# %%
# Navigate back to the main app directory if you're not already there
# %cd /content/Flux-Kontext-FaceLORA

# Use sed to comment out the line 'import spaces'
# This command finds line 3 and prepends it with a '#'
# !sed -i '3s/^/#/' app.py

# Optional: Display the first few lines of app.py to confirm the change
# !head -n 5 app.py
# Out:
# /content/Flux-Kontext-FaceLORA
# import gradio as gr
# import numpy as np
# #import spaces
# import torch
# import random

# %%
# !pip install huggingface_hub gradio --upgrade

# %%
# !python app.py
# Out:
# Streaming output truncated to the last 5000 lines.
#
# model-00002-of-00002.safetensors:  68% 3.06G/4.53G [01:38<00:28, 52.2MB/s]
#
# (…)pytorch_model-00001-of-00003.safetensors:  30% 2.98G/9.98G [01:38<02:48, 41.5MB/s]
#
#
#
#
#
# (…)pytorch_model-00002-of-00003.safetensors:  30% 2.96G/9.95G [01:38<03:26, 33.9MB/s]
#
#
#
# model-00001-of-00002.safetensors:  62% 3.08G/4.99G [01:40<01:34, 20.2MB/s]
#
#
#
#
#
#
# (…)pytorch_model-00003-of-00003.safetensors:  77% 3.00G/3.87G [01:40<01:04, 13.6MB/s]
#
# (…)pytorch_model-00001-of-00003.safetensors:  30% 2.99G/9.98G [01:40<08:38, 13.5MB/s]
#
#
# model-00002-of-00002.safetensors:  68% 3.07G/4.53G [01:40<01:46, 13.8MB/s]
#
#
#
#
#
# (…)pytorch_model-00002-of-00003.safetensors:  30% 2.97G/9.95G [01:40<08:31, 13.7MB/s]
#
#
#
#
#
#
# (…)pytorch_model-00003-of-00003.safetensors:  78% 3.01G/3.87G [01:40<00:47, 18.3MB/s]
#
#
#
#
#
# (…)pytorch_model-00002-of-00003.safetensors:  30% 2.98G/9.95G [01:40<06:19, 18.4MB/s]
#
#
# ...

# %%
# %cd /content/
# !git clone https://huggingface.co/spaces/ginigen/Flux-Kontext-FaceLORA
